# %%
import pandas as pd
from random import randint
import requests

# %%
zip_code = pd.read_excel('uszips.xlsx')
zip_code.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18005 -66.75218   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36074 -67.17519     Aguada       PR  Puerto Rico  True
# 2  603  18.45440 -67.12201  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16721 -66.93828    Maricao       PR  Puerto Rico  True
# 4  610  18.29032 -67.12244     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN     17113.0    102.7        72001    Adjuntas
# 1          NaN     37751.0    476.0        72003      Aguada
# 2          NaN     47081.0    574.9        72005   Aguadilla
# 3          NaN      6392.0     58.3        72093     Maricao
# 4          NaN     26686.0    286.9        72011      Añasco
#
#                                       county_weights  \
# 0                {"72001": "99.43", "72141": "0.57"}
# 1                                   {"72003": "100"}
# ...

# %%
num_zip, _ = zip_code.shape
rand_zip_index = randint(0, num_zip + 1)
code = zip_code['zip'][rand_zip_index]

# %%
code
# Out:
# 83468

# %%
api_key = 'c26df8e66267985116815eacb3b109f4'
response = requests.get('https://api.gateway.attomdata.com/propertyapi/v1.0.0/property/snapshot',
                        params={'postalcode': code},
                        headers={'apikey': api_key}
                       )
response.status_code
# Out:
# 200

# %%
response.json()['property']
# Out:
# [{'identifier': {'Id': 292348475,
#    'fips': '16059',
#    'apn': '001310000010',
#    'attomId': 292348475},
#   'lot': {'lotSize1': 37.28},
#   'address': {'country': 'US',
#    'countrySubd': 'ID',
#    'line1': '100 TURNER CIR',
#    'line2': 'TENDOY, ID 83468',
#    'locality': 'TENDOY',
#    'matchCode': 'ExaStr',
#    'oneLine': '100 TURNER CIR, TENDOY, ID 83468',
#    'postal1': '83468',
#    'postal2': ''},
#   'location': {'accuracy': 'Rooftop',
#    'latitude': '44.921029',
#    'longitude': '-113.630504',
#    'distance': 0.0,
#    'geoid': 'CO16059, CS1691886, DB1603030, SB0000083388, SB0000149196, ZI83468'},
#   'summary': {'propclass': 'Single Family Residence / Townhouse',
#    'propsubtype': 'Residential',
#    'proptype': 'MOBILE HOME',
#    'yearbuilt': 1979,
#    'propLandUse': 'MOBILE HOME',
#    'propIndicator': '10'},
#   'building': {'size': {'universalsize': 3556},
#    'rooms': {'bathstotal': 6.0, 'beds': 7}},
# ...
